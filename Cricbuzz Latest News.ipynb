# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'D:\python3.10.4\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'D:\python3.10.4\python.exe -m pip install --upgrade pip' command.

# %%
import  bs4
import time
from bs4 import BeautifulSoup
import sys
import requests  #for sending requests to a particular website
import pandas as pd

# %%
#Scraping the cricbuzz website

cric_buzz_info = requests.get("https://www.cricbuzz.com/")

time.sleep(2)  #when we keep requesting website might get us as a
               #bot so we should keep a delay between the requests we are sending
soup = BeautifulSoup(cric_buzz_info.text, 'html.parser') 
links = soup.find_all('div',attrs= {'class' :'cb-nws-intr'} )
links
# Out:
# [<div class="cb-nws-intr">The Indian captain implored curators to prepare better T20 tracks after the hosts crawled over the line in a chase of 100 in Lucknow</div>,
#  <div class="cb-nws-intr">South Africa's whit-ball captain has had plenty to feel bitter about recently. On Sunday life was sweet enough for him to venture into humour at a press conference</div>,
#  <div class="cb-nws-intr">The Shafali Verma-led side beat England in the final by seven wickets</div>,
#  <div class="cb-nws-intr">Green, who suffered a fractured finger during the home summer, has an appointment with the bone surgeon on Monday which will give a clearer picture of his readiness for Nagpur Test </div>,
#  <div class="cb-nws-intr">A night in the stands at Newlands showed how the SA20, with its tangled web of power, influence and contradiction, is offering a much-needed opportunity to leave the country's difficulties aside and party the lights out</div>,
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in links:
    print('->',i.text)
    
    print('/n')
# Out:
# -> The Indian captain implored curators to prepare better T20 tracks after the hosts crawled over the line in a chase of 100 in Lucknow
# /n
# -> South Africa's whit-ball captain has had plenty to feel bitter about recently. On Sunday life was sweet enough for him to venture into humour at a press conference
# /n
# -> The Shafali Verma-led side beat England in the final by seven wickets
# /n
# -> Green, who suffered a fractured finger during the home summer, has an appointment with the bone surgeon on Monday which will give a clearer picture of his readiness for Nagpur Test
# /n
# -> A night in the stands at Newlands showed how the SA20, with its tangled web of power, influence and contradiction, is offering a much-needed opportunity to leave the country's difficulties aside and party the lights out
# /n
# -> In her capacity as a mentor and advisor, the former India captain will also promote women's cricket and help develop the sport at the grassroots level in Gujarat
# /n
# ...
